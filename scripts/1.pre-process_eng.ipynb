# %%
# March 2025
# Script to preprocess data from wos and ce database
# Violeta Berdejo-Espinola

# %%
# %pip install fasttext-wheel

import pandas as pd
from pathlib import Path

# %%
# function to normalize text

def normalize_text(text):
    text = text.replace('<i>','')
    text = text.replace('</i>','')
    text = text.replace('*','')
    return text.lower().strip().capitalize()

# %% [markdown]
# # read wos data

# %%
# wos data

path = Path(f'../data/from_wos/')

# find broken files in wos folder

for file in path.glob("*.xls"):
    try:
        df = pd.read_excel(file)
        print(f"Successfully read {file}")
    except Exception as e:
        print(f"Error reading {file}: {e}")
# Out:
# Successfully read ../data/from_wos/id_278.xls
# Successfully read ../data/from_wos/id_254_3.xls
# Successfully read ../data/from_wos/id_244.xls
# Successfully read ../data/from_wos/id_76_3.xls
# Successfully read ../data/from_wos/id_235_2.xls
# Successfully read ../data/from_wos/id_76_11.xls
# Successfully read ../data/from_wos/id_213_1.xls
# Successfully read ../data/from_wos/id_94_4.xls
# Successfully read ../data/from_wos/id_31_1.xls
# Successfully read ../data/from_wos/id_17_2.xls
# Successfully read ../data/from_wos/id_134_2.xls
# Successfully read ../data/from_wos/id_109_2.xls
# Successfully read ../data/from_wos/id_126.xls
# Successfully read ../data/from_wos/id_101_11.xls
# Successfully read ../data/from_wos/id_49_1.xls
# Successfully read ../data/from_wos/id_28_1.xls
# Successfully read ../data/from_wos/id_195_2.xls
# Successfully read ../data/from_wos/id_269_2.xls
# Successfully read ../data/from_wos/id_90_1.xls
# Successfully read ../data/from_wos/id_252_4.xls
# Successfully read ../data/from_wos/id_64_10.xls
# Successfully read ../data/from_wos/id_109_3.xls
# Successfully read ../data/from_wos/id_17_3.xls
# Successfully read ../data/from_wos/id_76_10.xls
# Successfully read ../data/from_wos/id_94_5.xls
# Successfully read ../data/from_wos/id_235_3.xls
# Successfully read ../data/from_wos/id_110_2.xls
# Successfully read ../data/from_wos/id_136_1.xls
# Successfully read ../data/from_wos/id_50_1.xls
# Successfully read ../data/from_wos/id_15_1.xls
# Successfully read ../data/from_wos/id_245.xls
# Successfully read ../data/from_wos/id_76_2.xls
# Successfully read ../data/from_wos/id_135_14.xls
# Successfully read ../data/from_wos/id_254_2.xls
# Successfully read ../data/from_wos/id_279.xls
# Successfully read ../data/from_wos/id_237_1.xls
# Successfully read ../data/from_wos/id_237_3.xls
# Successfully read ../data/from_wos/id_15_3.xls
# Successfully read ../data/from_wos/id_253.xls
# Successfully read ../data/from_wos/id_136_3.xls
# Successfully read ../data/from_wos/id_213_2.xls
# Successfully read ../data/from_wos/id_94_7.xls
# Successfully read ../data/from_wos/id_235_1.xls
# Successfully read ../data/from_wos/id_17_1.xls
# Successfully read ../data/from_wos/id_31_2.xls
# Successfully read ../data/from_wos/id_134_1.xls
# Successfully read ../data/from_wos/id_109_1.xls
# Successfully read ../data/from_wos/id_215_4.xls
# Successfully read ../data/from_wos/id_37_4.xls
# Successfully read ../data/from_wos/id_03.xls
# Successfully read ../data/from_wos/id_114_4.xls
# Successfully read ../data/from_wos/id_49_2.xls
# Successfully read ../data/from_wos/id_188_5.xls
# Successfully read ../data/from_wos/id_195_1.xls
# Successfully read ../data/from_wos/id_28_2.xls
# Successfully read ../data/from_wos/id_269_1.xls
# Successfully read ../data/from_wos/id_188_4.xls
# Successfully read ../data/from_wos/id_326.xls
# Successfully read ../data/from_wos/id_90_2.xls
# Successfully read ../data/from_wos/id_231_4.xls
# Successfully read ../data/from_wos/id_49_3.xls
# Successfully read ../data/from_wos/id_130.xls
# Successfully read ../data/from_wos/id_02.xls
# Successfully read ../data/from_wos/id_118.xls
# Successfully read ../data/from_wos/id_94_6.xls
# Successfully read ../data/from_wos/id_213_3.xls
# Successfully read ../data/from_wos/id_136_2.xls
# Successfully read ../data/from_wos/id_110_1.xls
# Successfully read ../data/from_wos/id_76_1.xls
# Successfully read ../data/from_wos/id_15_2.xls
# Successfully read ../data/from_wos/id_50_2.xls
# Successfully read ../data/from_wos/id_237_2.xls
# Successfully read ../data/from_wos/id_254_1.xls
# Successfully read ../data/from_wos/id_256.xls
# Successfully read ../data/from_wos/id_242.xls
# Successfully read ../data/from_wos/id_76_5.xls
# Successfully read ../data/from_wos/id_135_13.xls
# Successfully read ../data/from_wos/id_254_5.xls
# Successfully read ../data/from_wos/id_313_2.xls
# Successfully read ../data/from_wos/id_08_3.xls
# Successfully read ../data/from_wos/id_136_6.xls
# Successfully read ../data/from_wos/id_17_4.xls
# Successfully read ../data/from_wos/id_94_2.xls
# Successfully read ../data/from_wos/id_235_4.xls
# Successfully read ../data/from_wos/id_129_1.xls
# Successfully read ../data/from_wos/id_69_2.xls
# Successfully read ../data/from_wos/id_120.xls
# Successfully read ../data/from_wos/id_37_1.xls
# Successfully read ../data/from_wos/id_276_2.xls
# Successfully read ../data/from_wos/id_250_1.xls
# Successfully read ../data/from_wos/id_109_4.xls
# Successfully read ../data/from_wos/id_215_1.xls
# Successfully read ../data/from_wos/id_132_2.xls
# Successfully read ../data/from_wos/id_114_1.xls
# Successfully read ../data/from_wos/id_252_3.xls
# Successfully read ../data/from_wos/id_175_1.xls
# Successfully read ../data/from_wos/id_252_2.xls
# Successfully read ../data/from_wos/id_274_1.xls
# Successfully read ../data/from_wos/id_231_1.xls
# Successfully read ../data/from_wos/id_56_1.xls
# Successfully read ../data/from_wos/id_188_1.xls
# Successfully read ../data/from_wos/id_276_3.xls
# Successfully read ../data/from_wos/id_07.xls
# Successfully read ../data/from_wos/id_13.xls
# Successfully read ../data/from_wos/id_236_10.xls
# Successfully read ../data/from_wos/id_69_3.xls
# Successfully read ../data/from_wos/id_94_3.xls
# Successfully read ../data/from_wos/id_17_5.xls
# Successfully read ../data/from_wos/id_249_1.xls
# Successfully read ../data/from_wos/id_08_2.xls
# Successfully read ../data/from_wos/id_313_3.xls
# Successfully read ../data/from_wos/id_135_12.xls
# Successfully read ../data/from_wos/id_254_4.xls
# Successfully read ../data/from_wos/id_255_10.xls
# Successfully read ../data/from_wos/id_76_4.xls
# Successfully read ../data/from_wos/id_76_6.xls
# Successfully read ../data/from_wos/id_15_5.xls
# Successfully read ../data/from_wos/id_313_1.xls
# Successfully read ../data/from_wos/id_237_5.xls
# Successfully read ../data/from_wos/id_254_6.xls
# Successfully read ../data/from_wos/id_135_10.xls
# Successfully read ../data/from_wos/id_136_5.xls
# Successfully read ../data/from_wos/id_249_3.xls
# Successfully read ../data/from_wos/id_17_7.xls
# Successfully read ../data/from_wos/id_129_2.xls
# Successfully read ../data/from_wos/id_213_4.xls
# Successfully read ../data/from_wos/id_94_1.xls
# Successfully read ../data/from_wos/id_69_1.xls
# Successfully read ../data/from_wos/id_37_2.xls
# Successfully read ../data/from_wos/id_123.xls
# Successfully read ../data/from_wos/id_215_2.xls
# Successfully read ../data/from_wos/id_250_2.xls
# Successfully read ../data/from_wos/id_276_1.xls
# Successfully read ../data/from_wos/id_49_4.xls
# Successfully read ../data/from_wos/id_114_2.xls
# Successfully read ../data/from_wos/id_107_8.xls
# Successfully read ../data/from_wos/id_132_1.xls
# Successfully read ../data/from_wos/id_188_3.xls
# Successfully read ../data/from_wos/id_56_3.xls
# Successfully read ../data/from_wos/id_231_3.xls
# Successfully read ../data/from_wos/id_274_3.xls
# Successfully read ../data/from_wos/id_17_11.xls
# Successfully read ../data/from_wos/id_175_2.xls
# Successfully read ../data/from_wos/id_17_10.xls
# Successfully read ../data/from_wos/id_231_2.xls
# Successfully read ../data/from_wos/id_274_2.xls
# Successfully read ../data/from_wos/id_252_1.xls
# Successfully read ../data/from_wos/id_308.xls
# Successfully read ../data/from_wos/id_188_2.xls
# Successfully read ../data/from_wos/id_56_2.xls
# Successfully read ../data/from_wos/id_107_9.xls
# Successfully read ../data/from_wos/id_114_3.xls
# Successfully read ../data/from_wos/id_49_5.xls
# Successfully read ../data/from_wos/id_215_3.xls
# Successfully read ../data/from_wos/id_250_3.xls
# Successfully read ../data/from_wos/id_37_3.xls
# Successfully read ../data/from_wos/id_10.xls
# Successfully read ../data/from_wos/id_213_5.xls
# Successfully read ../data/from_wos/id_17_6.xls
# Successfully read ../data/from_wos/id_249_2.xls
# Successfully read ../data/from_wos/id_136_4.xls
# Successfully read ../data/from_wos/id_08_1.xls
# Successfully read ../data/from_wos/id_283.xls
# Successfully read ../data/from_wos/id_254_7.xls
# Successfully read ../data/from_wos/id_135_11.xls
# Successfully read ../data/from_wos/id_237_4.xls
# Successfully read ../data/from_wos/id_15_4.xls
# Successfully read ../data/from_wos/id_76_7.xls
# Successfully read ../data/from_wos/id_216_6.xls
# Successfully read ../data/from_wos/id_227.xls
# Successfully read ../data/from_wos/id_174_5.xls
# Successfully read ../data/from_wos/id_131_5.xls
# Successfully read ../data/from_wos/id_107_13.xls
# Successfully read ../data/from_wos/id_117_6.xls
# Successfully read ../data/from_wos/id_108_1.xls
# Successfully read ../data/from_wos/id_115_4.xls
# Successfully read ../data/from_wos/id_209_1.xls
# Successfully read ../data/from_wos/id_196_2.xls
# Successfully read ../data/from_wos/id_151.xls
# Successfully read ../data/from_wos/id_16_1.xls
# Successfully read ../data/from_wos/id_30_2.xls
# Successfully read ../data/from_wos/id_156_2.xls
# Successfully read ../data/from_wos/id_88_2.xls
# Successfully read ../data/from_wos/id_135_1.xls
# Successfully read ../data/from_wos/id_190_4.xls
# Successfully read ../data/from_wos/id_236_3.xls
# Successfully read ../data/from_wos/id_14_3.xls
# Successfully read ../data/from_wos/id_187_15.xls
# Successfully read ../data/from_wos/id_187_14.xls
# Successfully read ../data/from_wos/id_172_2.xls
# Successfully read ../data/from_wos/id_137_2.xls
# Successfully read ../data/from_wos/id_32_1.xls
# Successfully read ../data/from_wos/id_77_1.xls
# Successfully read ../data/from_wos/id_14_2.xls
# Successfully read ../data/from_wos/id_236_2.xls
# Successfully read ../data/from_wos/id_210_1.xls
# Successfully read ../data/from_wos/id_255_1.xls
# Successfully read ../data/from_wos/id_156_3.xls
# Successfully read ../data/from_wos/id_88_3.xls
# Successfully read ../data/from_wos/id_150.xls
# Successfully read ../data/from_wos/id_62.xls
# Successfully read ../data/from_wos/id_196_3.xls
# Successfully read ../data/from_wos/id_115_5.xls
# Successfully read ../data/from_wos/id_194_1.xls
# Successfully read ../data/from_wos/id_29_2.xls
# Successfully read ../data/from_wos/id_174_4.xls
# Successfully read ../data/from_wos/id_107_12.xls
# Successfully read ../data/from_wos/id_131_4.xls
# Successfully read ../data/from_wos/id_232.xls
# Successfully read ../data/from_wos/id_57_4.xls
# Successfully read ../data/from_wos/id_226.xls
# Successfully read ../data/from_wos/id_216_7.xls
# Successfully read ../data/from_wos/id_216_5.xls
# Successfully read ../data/from_wos/id_218.xls
# Successfully read ../data/from_wos/id_117_5.xls
# Successfully read ../data/from_wos/id_131_6.xls
# Successfully read ../data/from_wos/id_107_10.xls
# Successfully read ../data/from_wos/id_174_6.xls
# Successfully read ../data/from_wos/id_194_3.xls
# Successfully read ../data/from_wos/id_187_9.xls
# Successfully read ../data/from_wos/id_108_2.xls
# Successfully read ../data/from_wos/id_209_2.xls
# Successfully read ../data/from_wos/id_196_1.xls
# Successfully read ../data/from_wos/id_146.xls
# Successfully read ../data/from_wos/id_30_1.xls
# Successfully read ../data/from_wos/id_16_2.xls
# Successfully read ../data/from_wos/id_135_2.xls
# Successfully read ../data/from_wos/id_88_1.xls
# Successfully read ../data/from_wos/id_156_1.xls
# Successfully read ../data/from_wos/id_68_4.xls
# Successfully read ../data/from_wos/id_191.xls
# Successfully read ../data/from_wos/id_255_3.xls
# Successfully read ../data/from_wos/id_210_3.xls
# Successfully read ../data/from_wos/id_77_3.xls
# Successfully read ../data/from_wos/id_32_3.xls
# Successfully read ../data/from_wos/id_64_9.xls
# Successfully read ../data/from_wos/id_187_16.xls
# Successfully read ../data/from_wos/id_192_4.xls
# Successfully read ../data/from_wos/id_137_1.xls
# Successfully read ../data/from_wos/id_172_1.xls
# Successfully read ../data/from_wos/id_14_1.xls
# Successfully read ../data/from_wos/id_64_8.xls
# Successfully read ../data/from_wos/id_77_2.xls
# Successfully read ../data/from_wos/id_32_2.xls
# Successfully read ../data/from_wos/id_255_2.xls
# Successfully read ../data/from_wos/id_210_2.xls
# Successfully read ../data/from_wos/id_236_1.xls
# Successfully read ../data/from_wos/id_135_3.xls
# Successfully read ../data/from_wos/id_61.xls
# Successfully read ../data/from_wos/id_16_3.xls
# Successfully read ../data/from_wos/id_115_6.xls
# Successfully read ../data/from_wos/id_187_8.xls
# Successfully read ../data/from_wos/id_29_1.xls
# Successfully read ../data/from_wos/id_194_2.xls
# Successfully read ../data/from_wos/id_131_7.xls
# Successfully read ../data/from_wos/id_174_7.xls
# Successfully read ../data/from_wos/id_117_4.xls
# Successfully read ../data/from_wos/id_219.xls
# Successfully read ../data/from_wos/id_216_4.xls
# Successfully read ../data/from_wos/id_57_3.xls
# Successfully read ../data/from_wos/id_189_3.xls
# Successfully read ../data/from_wos/id_174_3.xls
# Successfully read ../data/from_wos/id_131_3.xls
# Successfully read ../data/from_wos/id_107_15.xls
# Successfully read ../data/from_wos/id_309_2.xls
# Successfully read ../data/from_wos/id_73_2.xls
# Successfully read ../data/from_wos/id_277_1.xls
# Successfully read ../data/from_wos/id_115_2.xls
# Successfully read ../data/from_wos/id_157.xls
# Successfully read ../data/from_wos/id_16_7.xls
# Successfully read ../data/from_wos/id_128_2.xls
# Successfully read ../data/from_wos/id_95_1.xls
# Successfully read ../data/from_wos/id_68_1.xls
# Successfully read ../data/from_wos/id_190_2.xls
# Successfully read ../data/from_wos/id_135_7.xls
# Successfully read ../data/from_wos/id_229_2.xls
# Successfully read ../data/from_wos/id_156_4.xls
# Successfully read ../data/from_wos/id_88_4.xls
# Successfully read ../data/from_wos/id_77_6.xls
# Successfully read ../data/from_wos/id_14_5.xls
# Successfully read ../data/from_wos/id_312_1.xls
# Successfully read ../data/from_wos/id_236_5.xls
# Successfully read ../data/from_wos/id_149_3.xls
# Successfully read ../data/from_wos/id_255_6.xls
# Successfully read ../data/from_wos/id_187_13.xls
# Successfully read ../data/from_wos/id_187_12.xls
# Successfully read ../data/from_wos/id_192_1.xls
# Successfully read ../data/from_wos/id_255_7.xls
# Successfully read ../data/from_wos/id_149_2.xls
# Successfully read ../data/from_wos/id_236_4.xls
# Successfully read ../data/from_wos/id_14_4.xls
# Successfully read ../data/from_wos/id_156_5.xls
# Successfully read ../data/from_wos/id_88_5.xls
# Successfully read ../data/from_wos/id_229_3.xls
# Successfully read ../data/from_wos/id_135_6.xls
# Successfully read ../data/from_wos/id_190_3.xls
# Successfully read ../data/from_wos/id_16_6.xls
# Successfully read ../data/from_wos/id_70.xls
# Successfully read ../data/from_wos/id_115_3.xls
# Successfully read ../data/from_wos/id_174_2.xls
# Successfully read ../data/from_wos/id_309_3.xls
# Successfully read ../data/from_wos/id_107_14.xls
# Successfully read ../data/from_wos/id_131_2.xls
# Successfully read ../data/from_wos/id_117_1.xls
# Successfully read ../data/from_wos/id_230_2.xls
# Successfully read ../data/from_wos/id_216_1.xls
# Successfully read ../data/from_wos/id_71_1.xls
# Successfully read ../data/from_wos/id_57_2.xls
# Successfully read ../data/from_wos/id_189_2.xls
# Successfully read ../data/from_wos/id_216_3.xls
# Successfully read ../data/from_wos/id_107_16.xls
# Successfully read ../data/from_wos/id_309_1.xls
# Successfully read ../data/from_wos/id_117_3.xls
# Successfully read ../data/from_wos/id_73_1.xls
# Successfully read ../data/from_wos/id_55_2.xls
# Successfully read ../data/from_wos/id_277_2.xls
# Successfully read ../data/from_wos/id_115_1.xls
# Successfully read ../data/from_wos/id_154.xls
# Successfully read ../data/from_wos/id_16_4.xls
# Successfully read ../data/from_wos/id_72.xls
# Successfully read ../data/from_wos/id_95_2.xls
# Successfully read ../data/from_wos/id_128_1.xls
# Successfully read ../data/from_wos/id_190_1.xls
# Successfully read ../data/from_wos/id_68_2.xls
# Successfully read ../data/from_wos/id_88_7.xls
# Successfully read ../data/from_wos/id_156_7.xls
# Successfully read ../data/from_wos/id_229_1.xls
# Successfully read ../data/from_wos/id_135_4.xls
# Successfully read ../data/from_wos/id_14_6.xls
# Successfully read ../data/from_wos/id_77_5.xls
# Successfully read ../data/from_wos/id_32_5.xls
# Successfully read ../data/from_wos/id_255_5.xls
# Successfully read ../data/from_wos/id_312_2.xls
# Successfully read ../data/from_wos/id_236_6.xls
# Successfully read ../data/from_wos/id_192_3.xls
# Successfully read ../data/from_wos/id_187_10.xls
# Successfully read ../data/from_wos/id_187_11.xls
# Successfully read ../data/from_wos/id_192_2.xls
# Successfully read ../data/from_wos/id_236_7.xls
# Successfully read ../data/from_wos/id_149_1.xls
# Successfully read ../data/from_wos/id_255_4.xls
# Successfully read ../data/from_wos/id_77_4.xls
# Successfully read ../data/from_wos/id_32_4.xls
# Successfully read ../data/from_wos/id_14_7.xls
# Successfully read ../data/from_wos/id_135_5.xls
# Successfully read ../data/from_wos/id_88_6.xls
# Successfully read ../data/from_wos/id_98.xls
# Successfully read ../data/from_wos/id_156_6.xls
# Successfully read ../data/from_wos/id_68_3.xls
# Successfully read ../data/from_wos/id_95_3.xls
# Successfully read ../data/from_wos/id_67.xls
# Successfully read ../data/from_wos/id_16_5.xls
# Successfully read ../data/from_wos/id_155.xls
# Successfully read ../data/from_wos/id_117_2.xls
# Successfully read ../data/from_wos/id_107_17.xls
# Successfully read ../data/from_wos/id_131_1.xls
# Successfully read ../data/from_wos/id_174_1.xls
# Successfully read ../data/from_wos/id_194_4.xls
# Successfully read ../data/from_wos/id_216_2.xls
# Successfully read ../data/from_wos/id_230_1.xls
# Successfully read ../data/from_wos/id_189_1.xls
# Successfully read ../data/from_wos/id_57_1.xls
# Successfully read ../data/from_wos/id_71_2.xls
# Successfully read ../data/from_wos/id_307_2.xls
# Successfully read ../data/from_wos/id_321_1.xls
# Successfully read ../data/from_wos/id_205_5.xls
# Successfully read ../data/from_wos/id_187_3.xls
# Successfully read ../data/from_wos/id_178_1.xls
# Successfully read ../data/from_wos/id_38_2.xls
# Successfully read ../data/from_wos/id_185_1.xls
# Successfully read ../data/from_wos/id_05_2.xls
# Successfully read ../data/from_wos/id_66_1.xls
# Successfully read ../data/from_wos/id_23_1.xls
# Successfully read ../data/from_wos/id_158_4.xls
# Successfully read ../data/from_wos/id_170.xls
# Successfully read ../data/from_wos/id_42.xls
# Successfully read ../data/from_wos/id_145_1.xls
# Successfully read ../data/from_wos/id_135_8.xls
# Successfully read ../data/from_wos/id_100_1.xls
# Successfully read ../data/from_wos/id_64_3.xls
# Successfully read ../data/from_wos/id_203_3.xls
# Successfully read ../data/from_wos/id_255_9.xls
# Successfully read ../data/from_wos/id_124_1.xls
# Successfully read ../data/from_wos/id_147_2.xls
# Successfully read ../data/from_wos/id_181_4.xls
# Successfully read ../data/from_wos/id_255_8.xls
# Successfully read ../data/from_wos/id_203_2.xls
# Successfully read ../data/from_wos/id_246_2.xls
# Successfully read ../data/from_wos/id_21_2.xls
# Successfully read ../data/from_wos/id_64_2.xls
# Successfully read ../data/from_wos/id_80.xls
# Successfully read ../data/from_wos/id_135_9.xls
# Successfully read ../data/from_wos/id_171.xls
# Successfully read ../data/from_wos/id_43.xls
# Successfully read ../data/from_wos/id_254_14.xls
# Successfully read ../data/from_wos/id_282_6.xls
# Successfully read ../data/from_wos/id_38_3.xls
# Successfully read ../data/from_wos/id_323_2.xls
# Successfully read ../data/from_wos/id_187_2.xls
# Successfully read ../data/from_wos/id_205_4.xls
# Successfully read ../data/from_wos/id_119_1.xls
# Successfully read ../data/from_wos/id_321_2.xls
# Successfully read ../data/from_wos/id_307_1.xls
# Successfully read ../data/from_wos/id_60_4.xls
# Successfully read ../data/from_wos/id_178_2.xls
# Successfully read ../data/from_wos/id_185_2.xls
# Successfully read ../data/from_wos/id_38_1.xls
# Successfully read ../data/from_wos/id_23_2.xls
# Successfully read ../data/from_wos/id_66_2.xls
# Successfully read ../data/from_wos/id_282_4.xls
# Successfully read ../data/from_wos/id_05_1.xls
# Successfully read ../data/from_wos/id_55.xls
# Successfully read ../data/from_wos/id_41.xls
# Successfully read ../data/from_wos/id_173.xls
# Successfully read ../data/from_wos/id_198.xls
# Successfully read ../data/from_wos/id_156_8.xls
# Successfully read ../data/from_wos/id_82.xls
# Successfully read ../data/from_wos/id_100_2.xls
# Successfully read ../data/from_wos/id_145_2.xls
# Successfully read ../data/from_wos/id_236_9.xls
# Successfully read ../data/from_wos/id_147_1.xls
# Successfully read ../data/from_wos/id_124_2.xls
# Successfully read ../data/from_wos/id_246_1.xls
# Successfully read ../data/from_wos/id_203_1.xls
# Successfully read ../data/from_wos/id_236_8.xls
# Successfully read ../data/from_wos/id_64_1.xls
# Successfully read ../data/from_wos/id_14_8.xls
# Successfully read ../data/from_wos/id_21_1.xls
# Successfully read ../data/from_wos/id_100_3.xls
# Successfully read ../data/from_wos/id_83.xls
# Successfully read ../data/from_wos/id_156_9.xls
# Successfully read ../data/from_wos/id_97.xls
# Successfully read ../data/from_wos/id_40.xls
# Successfully read ../data/from_wos/id_166.xls
# Successfully read ../data/from_wos/id_282_5.xls
# Successfully read ../data/from_wos/id_66_3.xls
# Successfully read ../data/from_wos/id_185_3.xls
# Successfully read ../data/from_wos/id_178_3.xls
# Successfully read ../data/from_wos/id_323_1.xls
# Successfully read ../data/from_wos/id_187_1.xls
# Successfully read ../data/from_wos/id_119_2.xls
# Successfully read ../data/from_wos/id_321_3.xls
# Successfully read ../data/from_wos/id_205_3.xls
# Successfully read ../data/from_wos/id_200.xls
# Successfully read ../data/from_wos/id_228.xls
# Successfully read ../data/from_wos/id_141_3.xls
# Successfully read ../data/from_wos/id_187_5.xls
# Successfully read ../data/from_wos/id_207_1.xls
# Successfully read ../data/from_wos/id_178_7.xls
# Successfully read ../data/from_wos/id_60_1.xls
# Successfully read ../data/from_wos/id_25_1.xls
# Successfully read ../data/from_wos/id_165_2.xls
# Successfully read ../data/from_wos/id_185_7.xls
# Successfully read ../data/from_wos/id_162.xls
# Successfully read ../data/from_wos/id_158_2.xls
# Successfully read ../data/from_wos/id_254_13.xls
# Successfully read ../data/from_wos/id_282_1.xls
# Successfully read ../data/from_wos/id_93.xls
# Successfully read ../data/from_wos/id_259_2.xls
# Successfully read ../data/from_wos/id_87.xls
# Successfully read ../data/from_wos/id_18_1.xls
# Successfully read ../data/from_wos/id_301_2.xls
# Successfully read ../data/from_wos/id_139_3.xls
# Successfully read ../data/from_wos/id_64_5.xls
# Successfully read ../data/from_wos/id_238_3.xls
# Successfully read ../data/from_wos/id_181_3.xls
# Successfully read ../data/from_wos/id_181_2.xls
# Successfully read ../data/from_wos/id_238_2.xls
# Successfully read ../data/from_wos/id_64_4.xls
# Successfully read ../data/from_wos/id_139_2.xls
# Successfully read ../data/from_wos/id_100_6.xls
# Successfully read ../data/from_wos/id_86.xls
# Successfully read ../data/from_wos/id_79.xls
# Successfully read ../data/from_wos/id_254_12.xls
# Successfully read ../data/from_wos/id_177.xls
# Successfully read ../data/from_wos/id_158_3.xls
# Successfully read ../data/from_wos/id_163.xls
# Successfully read ../data/from_wos/id_185_6.xls
# Successfully read ../data/from_wos/id_318_2.xls
# Successfully read ../data/from_wos/id_165_3.xls
# Successfully read ../data/from_wos/id_178_6.xls
# Successfully read ../data/from_wos/id_187_4.xls
# Successfully read ../data/from_wos/id_167_1.xls
# Successfully read ../data/from_wos/id_122_1.xls
# Successfully read ../data/from_wos/id_104_2.xls
# Successfully read ../data/from_wos/id_141_2.xls
# Successfully read ../data/from_wos/id_27_2.xls
# Successfully read ../data/from_wos/id_44_1.xls
# Successfully read ../data/from_wos/id_216_8.xls
# Successfully read ../data/from_wos/id_205_2.xls
# Successfully read ../data/from_wos/id_187_6.xls
# Successfully read ../data/from_wos/id_178_4.xls
# Successfully read ../data/from_wos/id_207_2.xls
# Successfully read ../data/from_wos/id_25_2.xls
# Successfully read ../data/from_wos/id_60_2.xls
# Successfully read ../data/from_wos/id_165_1.xls
# Successfully read ../data/from_wos/id_185_4.xls
# Successfully read ../data/from_wos/id_158_1.xls
# Successfully read ../data/from_wos/id_161.xls
# Successfully read ../data/from_wos/id_53.xls
# Successfully read ../data/from_wos/id_282_2.xls
# Successfully read ../data/from_wos/id_254_10.xls
# Successfully read ../data/from_wos/id_84.xls
# Successfully read ../data/from_wos/id_100_4.xls
# Successfully read ../data/from_wos/id_259_1.xls
# Successfully read ../data/from_wos/id_18_2.xls
# Successfully read ../data/from_wos/id_301_1.xls
# Successfully read ../data/from_wos/id_64_6.xls
# Successfully read ../data/from_wos/id_181_1.xls
# Successfully read ../data/from_wos/id_238_1.xls
# Successfully read ../data/from_wos/id_64_7.xls
# Successfully read ../data/from_wos/id_139_1.xls
# Successfully read ../data/from_wos/id_84_2.xls
# Successfully read ../data/from_wos/id_91.xls
# Successfully read ../data/from_wos/id_100_5.xls
# Successfully read ../data/from_wos/id_254_11.xls
# Successfully read ../data/from_wos/id_282_3.xls
# Successfully read ../data/from_wos/id_160.xls
# Successfully read ../data/from_wos/id_52.xls
# Successfully read ../data/from_wos/id_46.xls
# Successfully read ../data/from_wos/id_185_5.xls
# Successfully read ../data/from_wos/id_318_1.xls
# Successfully read ../data/from_wos/id_60_3.xls
# Successfully read ../data/from_wos/id_178_5.xls
# Successfully read ../data/from_wos/id_187_7.xls
# Successfully read ../data/from_wos/id_141_1.xls
# Successfully read ../data/from_wos/id_104_1.xls
# Successfully read ../data/from_wos/id_122_2.xls
# Successfully read ../data/from_wos/id_167_2.xls
# Successfully read ../data/from_wos/id_44_2.xls
# Successfully read ../data/from_wos/id_27_1.xls
# Successfully read ../data/from_wos/id_205_1.xls
# Successfully read ../data/from_wos/id_265.xls
# Successfully read ../data/from_wos/id_239_6.xls
# Successfully read ../data/from_wos/id_263_1.xls
# Successfully read ../data/from_wos/id_127_1.xls
# Successfully read ../data/from_wos/id_144_2.xls
# Successfully read ../data/from_wos/id_101_2.xls
# Successfully read ../data/from_wos/id_09.xls
# Successfully read ../data/from_wos/id_184_2.xls
# Successfully read ../data/from_wos/id_39_1.xls
# Successfully read ../data/from_wos/id_107_4.xls
# Successfully read ../data/from_wos/id_63_6.xls
# Successfully read ../data/from_wos/id_320_2.xls
# Successfully read ../data/from_wos/id_304.xls
# Successfully read ../data/from_wos/id_320_3.xls
# Successfully read ../data/from_wos/id_107_5.xls
# Successfully read ../data/from_wos/id_106.xls
# Successfully read ../data/from_wos/id_34.xls
# Successfully read ../data/from_wos/id_20.xls
# Successfully read ../data/from_wos/id_322_1.xls
# Successfully read ../data/from_wos/id_112.xls
# Successfully read ../data/from_wos/id_144_3.xls
# Successfully read ../data/from_wos/id_101_3.xls
# Successfully read ../data/from_wos/id_239_7.xls
# Successfully read ../data/from_wos/id_125_2.xls
# Successfully read ../data/from_wos/id_270.xls
# Successfully read ../data/from_wos/id_261_2.xls
# Successfully read ../data/from_wos/id_65_1.xls
# Successfully read ../data/from_wos/id_281_5.xls
# Successfully read ../data/from_wos/id_76_9.xls
# Successfully read ../data/from_wos/id_65_3.xls
# Successfully read ../data/from_wos/id_272.xls
# Successfully read ../data/from_wos/id_254_9.xls
# Successfully read ../data/from_wos/id_266.xls
# Successfully read ../data/from_wos/id_299.xls
# Successfully read ../data/from_wos/id_239_5.xls
# Successfully read ../data/from_wos/id_17_8.xls
# Successfully read ../data/from_wos/id_159_4.xls
# Successfully read ../data/from_wos/id_263_2.xls
# Successfully read ../data/from_wos/id_101_1.xls
# Successfully read ../data/from_wos/id_144_1.xls
# Successfully read ../data/from_wos/id_127_2.xls
# Successfully read ../data/from_wos/id_138.xls
# Successfully read ../data/from_wos/id_36.xls
# Successfully read ../data/from_wos/id_39_2.xls
# Successfully read ../data/from_wos/id_184_1.xls
# Successfully read ../data/from_wos/id_107_7.xls
# Successfully read ../data/from_wos/id_63_5.xls
# Successfully read ../data/from_wos/id_320_1.xls
# Successfully read ../data/from_wos/id_140_4.xls
# Successfully read ../data/from_wos/id_63_4.xls
# Successfully read ../data/from_wos/id_107_6.xls
# Successfully read ../data/from_wos/id_322_2.xls
# Successfully read ../data/from_wos/id_105.xls
# Successfully read ../data/from_wos/id_159_5.xls
# Successfully read ../data/from_wos/id_17_9.xls
# Successfully read ../data/from_wos/id_125_1.xls
# Successfully read ../data/from_wos/id_239_4.xls
# Successfully read ../data/from_wos/id_267.xls
# Successfully read ../data/from_wos/id_261_1.xls
# Successfully read ../data/from_wos/id_254_8.xls
# Successfully read ../data/from_wos/id_65_2.xls
# Successfully read ../data/from_wos/id_281_4.xls
# Successfully read ../data/from_wos/id_76_8.xls
# Successfully read ../data/from_wos/id_159_1.xls
# Successfully read ../data/from_wos/id_258_1.xls
# Successfully read ../data/from_wos/id_144_4.xls
# Successfully read ../data/from_wos/id_182_2.xls
# Successfully read ../data/from_wos/id_33.xls
# Successfully read ../data/from_wos/id_243_2.xls
# Successfully read ../data/from_wos/id_206_2.xls
# Successfully read ../data/from_wos/id_107_2.xls
# Successfully read ../data/from_wos/id_303.xls
# Successfully read ../data/from_wos/id_320_4.xls
# Successfully read ../data/from_wos/id_317.xls
# Successfully read ../data/from_wos/id_140_1.xls
# Successfully read ../data/from_wos/id_45_2.xls
# Successfully read ../data/from_wos/id_63_1.xls
# Successfully read ../data/from_wos/id_316.xls
# Successfully read ../data/from_wos/id_302.xls
# Successfully read ../data/from_wos/id_107_3.xls
# Successfully read ../data/from_wos/id_319_1.xls
# Successfully read ../data/from_wos/id_114.xls
# Successfully read ../data/from_wos/id_144_5.xls
# Successfully read ../data/from_wos/id_324_1.xls
# Successfully read ../data/from_wos/id_239_1.xls
# Successfully read ../data/from_wos/id_281_1.xls
# Successfully read ../data/from_wos/id_262.xls
# Successfully read ../data/from_wos/id_281_3.xls
# Successfully read ../data/from_wos/id_239_3.xls
# Successfully read ../data/from_wos/id_94_8.xls
# Successfully read ../data/from_wos/id_159_2.xls
# Successfully read ../data/from_wos/id_258_2.xls
# Successfully read ../data/from_wos/id_182_1.xls
# Successfully read ../data/from_wos/id_116.xls
# Successfully read ../data/from_wos/id_206_1.xls
# Successfully read ../data/from_wos/id_24.xls
# Successfully read ../data/from_wos/id_243_1.xls
# Successfully read ../data/from_wos/id_102.xls
# Successfully read ../data/from_wos/id_107_1.xls
# Successfully read ../data/from_wos/id_319_3.xls
# Successfully read ../data/from_wos/id_314.xls
# Successfully read ../data/from_wos/id_300.xls
# Successfully read ../data/from_wos/id_63_3.xls
# Successfully read ../data/from_wos/id_140_3.xls
# Successfully read ../data/from_wos/id_140_2.xls
# Successfully read ../data/from_wos/id_63_2.xls
# Successfully read ../data/from_wos/id_45_1.xls
# Successfully read ../data/from_wos/id_315.xls
# Successfully read ../data/from_wos/id_319_2.xls
# Successfully read ../data/from_wos/id_19.xls
# Successfully read ../data/from_wos/id_103.xls
# Successfully read ../data/from_wos/id_258_3.xls
# Successfully read ../data/from_wos/id_144_6.xls
# Successfully read ../data/from_wos/id_324_2.xls
# Successfully read ../data/from_wos/id_159_3.xls
# Successfully read ../data/from_wos/id_94_9.xls
# Successfully read ../data/from_wos/id_239_2.xls
# Successfully read ../data/from_wos/id_281_2.xls

# %%
# read all xls files in the folder into a list of dfs
path = Path(f'../data/from_wos/')
dfs = [pd.read_excel(file) for file in path.glob("*.xls")]

# concatenate dfs into one master df

df_concat = pd.concat(dfs, ignore_index=True)
print(f"unique journal names {df_concat['Source Title'].nunique()}")

# rename columns

df_master = df_concat.rename(columns={
    'Article Title': 'title',
    'Abstract': 'abstract',
    'Source Title': 'journal',
    'Authors': 'authors',
    'Publication Year': 'year'
})

# normalize journal name

df_master["journal"] = df_master["journal"].apply(normalize_text)

# normalize article title
 
df_master['title'] = df_master['title'].apply(normalize_text)

# subset metadata

df_repo = df_master.loc[:,['title', 'abstract', 'journal', 'year', 'authors']]
print(f'NAs in repo:\n{df_repo.isna().sum()}')
print(f'articles in repo raw: {len(df_repo)}')

# create df of nas and duplicates

df_repo_nas = df_repo[df_repo['abstract'].isna() | df_repo['authors'].isna()]
df_repo_dupes = df_repo[df_repo.duplicated(subset=['title','authors'], keep=False)]

# remove unwanted articles 

df_repo = df_repo[~df_repo["title"].str.contains("In Memoriam|Editorial|Correction|Notes|Untitled|Retracted")]
print(f'articles in repo: {len(df_repo)} -> editorials, in memoriam removed')

# remove nas and duplicates

df_repo = df_repo.dropna(subset='authors', how='any').dropna(subset='abstract', how='any').drop_duplicates(subset=['title','abstract'], keep='first')

print(f'articles in repo: {len(df_repo)} -> nas, duplicates removed')
print(f"unique journals in repo {df_repo['journal'].nunique()}")

# create journal list

repo_journals = df_repo['journal'].unique()
# Out:
# unique journal names 286
# NAs in repo:
# title           0
# abstract    77831
# journal         0
# year            0
# authors        69
# dtype: int64
# articles in repo raw: 525433
# articles in repo: 523393 -> editorials, in memoriam removed
# articles in repo: 440346 -> nas, duplicates removed
# unique journals in repo 274

# %% [markdown]
# # detect language of titles in repo

# %%
from fasttext.FastText import _FastText

model_path = 'lid.176.ftz'
model = _FastText(model_path=model_path)

# function to detect languages

def get_lang(text: str) -> str:
    lang, _ = model.predict(text)
    lang = lang[0].removeprefix('__label__')
    # conf = conf[0]

    return lang

# detect languages

df_repo["language"] = df_repo["title"].apply(get_lang)

print(df_repo["language"].value_counts())

# filter english only

df_repo = df_repo[df_repo['language'] == 'en']
df_repo = df_repo.reset_index()

print(f'articles in repo: {len(df_repo)} -> non-english language articles removed')
# Out:
# language
# en     437737
# es        585
# it        304
# de        291
# fr        277
# hr        254
# pt        182
# ceb       174
# pl        134
# sv         84
# ca         58
# nl         56
# br         35
# la         26
# no         21
# fi         19
# id         19
# eo         14
# hu          9
# eu          6
# vi          6
# tr          5
# ru          4
# kn          4
# zh          4
# gl          3
# cy          3
# sl          3
# war         3
# fy          2
# uk          2
# ro          2
# oc          2
# ja          2
# nn          2
# fa          2
# lt          2
# als         1
# bn          1
# si          1
# hi          1
# bar         1
# lb          1
# nah         1
# sr          1
# cs          1
# et          1
# Name: count, dtype: int64
# articles in repo: 437737 -> non-english language articles removed

# %%
# save to disk
df_repo.to_csv('../data/outputs_pre-processing/repo_eng_pre-processed.csv', encoding='utf=8', index=False) 
df_repo_nas.to_csv("../data/outputs_pre-processing/repo_eng_nas_removed.csv", encoding='utf-8', index=False)
df_repo_dupes.to_csv("../data/outputs_pre-processing/repo_eng_duplicates_removed.csv", encoding='utf-8', index=False)

# %% [markdown]
# # read pos data

# %%
# ce data 
df_pos = pd.read_csv('../data/from_ce/all_ce_relevant_papers.csv', encoding='utf-8')

# rename columns

df_pos.rename(columns={
    'Title': 'title',
    'Citation': 'citation',
    'Publication_year': 'year'
}, inplace=True)

# normalize title 

df_pos['title'] = [normalize_text(str(title)) for title in df_pos['title']]

# subset metadata

df_pos = df_pos.loc[:,['title','citation','year']] 
print(f'NAs in pos:\n{df_pos.isna().sum()}')
print(f'articles in positives raw: {len(df_pos)}')

# create df of nas and duplicates

df_pos_nas = df_pos[df_pos['title'].isna().isna()] # is zero
df_pos_dupes = df_pos[df_pos.duplicated(subset=['title'], keep=False)]

# drop nas and duplicates

df_pos = df_pos.dropna(subset='title', how='any').drop_duplicates(subset=['title','citation'], keep='first').drop_duplicates(subset=['title'], keep='first')
print(f'articles in positives: {len(df_pos)} -> nas and duplicates removed')

df_pos = df_pos.reset_index()
# Out:
# NAs in pos:
# title        0
# citation     0
# year        15
# dtype: int64
# articles in positives raw: 15647
# articles in positives: 10589 -> nas and duplicates removed

# %% [markdown]
# # detect language of titles in pos

# %%
# detect languages

df_pos["language"] = df_pos["title"].apply(get_lang)

# filter english only

df_pos_noneng = df_pos[df_pos['language'] != 'en']
df_pos_eng = df_pos[df_pos['language'] == 'en']
# df_pos = df_pos.reset_index()

print(f'articles in positives: {len(df_pos_eng)} -> english articles')
print(f'articles in positives removed: {len(df_pos_noneng)} -> non-english language articles')
print(df_pos["language"].value_counts())
# Out:
# articles in positives: 9117 -> english articles
# articles in positives removed: 1472 -> non-english language articles
# language
# en     9117
# ja      409
# de      312
# es      135
# zh      126
# fr      106
# ru       81
# pt       67
# pl       62
# hu       52
# ko       49
# it       34
# ar        9
# fa        8
# nl        7
# sv        2
# ceb       2
# cs        2
# ca        2
# tr        2
# vi        2
# uk        1
# bn        1
# ur        1
# Name: count, dtype: int64

# %%
# save to disk 
df_pos.to_csv('../data/outputs_pre-processing/pos_eng_pre-processed.csv', encoding='utf-8', index=False) 
df_pos_dupes.to_csv('../data/outputs_pre-processing/pos_eng_duplicates_removed.csv', encoding='utf-8', index=False)
df_pos_noneng.to_csv('../data/outputs_pre-processing/pos_eng_noneng_removed.csv', encoding='utf-8', index=False)

# %% [markdown]
# # remove journals in pos that are not indexed in wos

# %% [markdown]
# positive df doesn't have a journal column, but it has a citation column, so we extact the journal name from the citation string

# %%
# function to extract journal name from citation
def get_journal_name(citation):
    position1 = citation.rfind('<i>') # finds the position where the pattern appears in text
    position2 = citation.rfind('</i>')
    if position1 == -1: # -1 means error/not found
        return ""
    
    return citation[position1+3:position2]

# %%
# get journal names in positive list 

pos_journals = df_pos['citation'].apply(get_journal_name)

# normalize journal names

pos_journals = pos_journals.apply(normalize_text)

# add list of journal names to df_pos

df_pos['journal'] = pos_journals

# get unique journal names

pos_journals = set(pos_journals)
pos_journals.remove("")
print(f'unique journals in positives {len(pos_journals)} >> this includes english and non-english journals')

# remove journals in pos_journals that are not in repo_journals

df_repo_in_pos_journal = df_repo[df_repo['journal'].isin(pos_journals)]
df_repo_in_pos_journal = df_repo_in_pos_journal.drop_duplicates(subset="title")
pos_journals_in_wos = df_repo_in_pos_journal['journal'].unique()

print(f"unique journals in positives that are available in wos {len(pos_journals_in_wos)}")
print(f'articles in repo that are from the journals in pos {len(df_repo_in_pos_journal)}')

# remove journals from df_pos that are not in df_repo

df_pos_in_wos = df_pos[df_pos['journal'].isin(pos_journals_in_wos)]
print(f'articles in pos available in wos {len(df_pos_in_wos)}')

# sorted(pos_journals) 

# read me 
# after inspection I found that journal names that are in blank or are long titles belong to reports that do not follow the journal citation pattern
# Out:
# unique journals in positives 1183 >> this includes english and non-english journals
# unique journals in positives that are available in wos 186
# articles in repo that are from the journals in pos 378466
# articles in pos available in wos 5474

# %%
# save to disk 

df_pos_in_wos.to_csv('../data/outputs_pre-processing/pos_eng_metadta.csv', encoding='utf-8', index=False)
df_repo_in_pos_journal.to_csv('../data/outputs_pre-processing/repo_eng_metadata.csv', encoding='utf-8', index=False)

# %%
# data imbalance

len(df_pos_in_wos)/len(df_repo_in_pos_journal)*100
# Out:
# 1.4463650631760845
